# %%
from configs.config import Config
from data.data_utils import *
from train.training import Trainer

train_loader = load_data(True, True, Config.batch_size)
trainer = Trainer()
trainer.initialize()
trainer.train(
    n_epochs=Config.n_epochs,
    dataloader=train_loader
)
# Out:
# Use GPU: False
# Using downloaded and verified file: ./../data/cifar-10-python.tar.gz
# Extracting ./../data/cifar-10-python.tar.gz to ./../data
#   0%|          | 0/391 [00:00<?, ?it/s]
# Pretrained initial state
# torch.Size([3, 32, 32])
# torch.Size([3, 32, 32])
# torch.Size([3, 32, 32])
# /home/ali/PycharmProjects/MPGAN/utils/image_utils.py:18: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3 negative Z values that have been clipped to zero
#   img = lab2rgb(image_tensor.permute((1, 2, 0)))
# KeyboardInterrupt
